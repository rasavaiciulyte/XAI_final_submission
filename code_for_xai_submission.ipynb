# %% [markdown]
# # XAI final submission: Interpretable Anomaly Detection – How explainability helps detect malicious network traffic, like cyber attacks.

# %% [markdown]
# ## Loading Data, Importing libraries needed for the project

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import os

from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, recall_score, f1_score

import lime
import dice_ml
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 11
#       8 from sklearn.metrics import accuracy_score, recall_score, f1_score
#      10 import lime
# ---> 11 import dice_ml
#
# ModuleNotFoundError: No module named 'dice_ml'

# %% [markdown]
# ## Preprocesing Data

# %% [markdown]
# ## Training the model

# %% [markdown]
# ## XAI implementations

# %% [markdown]
# ### LIME

# %% [markdown]
# ### DICE
